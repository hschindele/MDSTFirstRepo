# %%
import checkpoint1b as ch
import pandas as pd

# %%
df = pd.read_csv('../data/starbucks.csv')
df.head(150)
# Out:
#            Beverage_category                                         Beverage  \
# 0                     Coffee                                    Brewed Coffee
# 1                     Coffee                                    Brewed Coffee
# 2                     Coffee                                    Brewed Coffee
# 3                     Coffee                                    Brewed Coffee
# 4    Classic Espresso Drinks                                      Caffè Latte
# ..                       ...                                              ...
# 145         Tazo® Tea Drinks  Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)
# 146         Tazo® Tea Drinks  Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)
# 147         Tazo® Tea Drinks  Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)
# 148         Tazo® Tea Drinks  Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)
# 149         Tazo® Tea Drinks  Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)
#
# ...

# %%
df = ch.fill_zero_iron(df)
df["Caffeine (mg)"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      175
# 1      260
# 2      330
# 3      410
# 4       75
#       ...
# 237      0
# 238      0
# 239      0
# 240      0
# 241      0
# Name: Caffeine (mg), Length: 242, dtype: object>

# %%
df = ch.fix_strings(df, 'Beverage_category')
df = ch.fix_caffeine(df)
df.head(150)
# Out:
# /Users/hschindele/Desktop/MDST/mdst_tutorials/checkpoint1/checkpoint1b.py:43: FutureWarning: The default value of regex will change from True to False in a future version.
#   df[col] = df[col].str.replace('[^a-zA-Z,^" "]', '')
#            Beverage_category                                         Beverage  \
# 0                     coffee                                    Brewed Coffee
# 1                     coffee                                    Brewed Coffee
# 2                     coffee                                    Brewed Coffee
# 3                     coffee                                    Brewed Coffee
# 4    classic espresso drinks                                      Caffè Latte
# ..                       ...                                              ...
# 145          tazo tea drinks  Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)
# 146          tazo tea drinks  Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)
# ...

# %%
df = ch.standardize_names(df)
df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-ff023a23cfab> in <module>
# ----> 1 df = ch.standardize_names(df)
#       2 df.head()
#
# ~/Desktop/MDST/mdst_tutorials/checkpoint1/checkpoint1b.py in standardize_names(df)
#      36 def standardize_names(df):
#      37     df.columns = map(str.lower, df.columns)
# ---> 38     df.columns = map(str.replace(r"\(.*\)",""), df.columns)
#      39     return df
#      40
#
# TypeError: replace expected at least 2 arguments, got 1
